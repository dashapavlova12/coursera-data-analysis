# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import plotly.graph_objects as go

# %%
# %matplotlib inline

# %%
import os
from google.colab import files #если работаешь локально, закомменти
files.upload() #если работаешь локально, закомменти
os.listdir()
# Out:
#      <input type="file" id="files-bafbd8af-71d3-4300-8540-2247b90eb824" name="files[]" multiple disabled />
#      <output id="result-bafbd8af-71d3-4300-8540-2247b90eb824">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving CompleteDataset.csv to CompleteDataset.csv
# ['.config', 'CompleteDataset.csv', 'sample_data']

# %%
df = pd.read_csv("CompleteDataset.csv")
# Out:
# /usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning:
#
# Columns (23,35) have mixed types.Specify dtype option on import or set low_memory=False.

# %% [markdown]
# ## Графики нужно смотреть в google collab

# %% [markdown]
# Текстовое описание : визуализация гистограммы возраста игроков, больше всего игроков имеют возраст 20-25 лет, после 40 лет игрок, как правило, завершает карьеру. Карьера начинается с 16 лет.

# %% [markdown]
# Гистограмма возраста укажет на доминирующий возраст и особенности распределения

# %%
ax = df.Age.plot.hist()
ax.set_title("Age bar graph", fontdict = {'fontsize' : 15})
plt.legend()
plt.xlabel('Age')
# Out:
# Text(0.5, 0, 'Age')
